# %% [markdown]
# <a href="https://colab.research.google.com/github/srishenba/day9/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name=str(input("Enter your name:"))
age=int(input("Enter your age:"))
college=str(input("Enter your college name:"))
dept=str(input("Enter your department:"))
print(f"My name is {name}")
print(f"I am {age}years old")
print("I study at {college}college")
print(f"Department{dept}")

# %%
a=int(input("Enter a number:"))
b=int(input("Enter a number:"))
print(f"The sum of {a} and {b} is {a+b}")
print(f"The difference of {a} and {b} is {a-b}")
print(f"The product of {a} and {b} is {a*b}")

# %%
n=int(input("Enter celsius:"))
f=(n*9/5)+32
print(f"The fahrenheit is {f}")

# %%
n=int(input("Enter INR:"))
USD=n*0.013
print(f"The USD is {USD}")

# %%
l=int(input("Enter length:"))
b=int(input("Enter breadth:"))
print(f"The area of rectangle is {l*b}")

# %%
tamil=int(input("Enter tamil marks:"))
english=int(input("Enter english marks:"))
maths=int(input("Enter maths marks:"))
science=int(input("Enter science marks:"))
social=int(input("Enter social marks:"))
total=tamil+english+maths+science+social
average=tamil+english+maths+science+social/5
print(f"The total is {total}")
print(f"The Average is{average}")

# %%
a=int(input("Enter a number:"))
b=int(input("Enter a number:"))
a,b=b,a
print(f"The value of a is {a}")
print(f"The value of b is {b}")

# %% [markdown]
# # New Section

# %%
height=int(input("Enter height:"))
weight=float(input("Enter weight:"))
BMI=weight/(height/100)**2
print(f"The BMI is {BMI}")

# %%
hours=int(input("Enter hours:"))
seconds=hours*60*60
minutes=hours*60
print(f"The seconds is {seconds}")
print(f"The minutes is {minutes}")

# %%
n=int(input("Enter a number:"))
if (n<5):
  print("Free ticket")
elif (5<n<17):
  print("Child ticket")
elif(n<18):
  print("Adult ticket")

# %%
units=int(input("Enter units:"))
if (units<=100):
   print("rupee 0")
else:
  (units>100)
  units=units*5
  print("Bill")

# %%
num=int(input("Enter Number:"))
if (num%3==0 and num%5==0):
  print("Divisible by 3 and 5")
else:
  print("Not Divisible by 3 and 5")

# %%
attendance =int(input("enter attendance:"))
if (attendance>=75):
  print("Eligible for exam")
else:
   (attendance<75)
   print("Not Eligible for exam")

# %%
amount=int(input("Enter amount:"))
if (amount>=500):
  print("10% cashback")
else:
   (amount<=500)
   print("No cashback")
